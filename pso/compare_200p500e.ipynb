# %%
import numpy as np
from freelunch import PSO, PAO, benchmarks
import statistics
from PSO import PSO as PSO_h
from iwPSO import iwPSO
from DNLPSO import DNLPSO_simple
from functions import rastrigin

# %%
data = {'pso_fr':{}, 'pao':{}, 'pso_':{}, 'iwpso':{}, 'dnlpso':{}}

# %%
# for d in [2,5,10,30,50]:
#     pso = PSO(benchmarks.Ragstrin(n=d),bounds=np.array([[-5.12,5.12]]*d))
#     pso.hypers.update({'N':200, 'G':500})
#     runs = []
#     for _ in range(30):
#         runs.append(rastrigin(pso())[0])
#     print(f'''PSO-FREELUNCH
# Dim: {d}
# Mean: {statistics.mean(runs)}
# Stdev: {statistics.stdev(runs)}
# Min: {min(runs)}
# Max: {max(runs)}
# Mean: {statistics.mean(runs)}
# ''')
#     data['pso_'][d] = {'dim':d, 'mean':statistics.mean(runs), 'stdev':statistics.stdev(runs),'min':min(runs),'max':max(runs)}

# %%
for d in [2,5,10,30,50]:
    pao = PAO(benchmarks.Ragstrin(n=d),bounds=np.array([[-5.12,5.12]]*d))
    pao.hypers.update({'N':200, 'G':500})
    runs = []
    for _ in range(30):
        runs.append(rastrigin(pao())[0])
    print(f'''PAO
Dim: {d}
Mean: {statistics.mean(runs)}
Stdev: {statistics.stdev(runs)}
Min: {min(runs)}
Max: {max(runs)}
Mean: {statistics.mean(runs)}
''')
    data['pao'][d] = {'dim':d, 'mean':statistics.mean(runs), 'stdev':statistics.stdev(runs),'min':min(runs),'max':max(runs)}
# Out:
# PAO
# Dim: 2
# Mean: 0.0
# Stdev: 0.0
# Min: 0.0
# Max: 0.0
# Mean: 0.0
#
# PAO
# Dim: 5
# Mean: 0.06633060380621932
# Stdev: 0.25242920349558223
# Min: 0.0
# Max: 0.9949590570932898
# Mean: 0.06633060380621932
#
# PAO
# Dim: 10
# Mean: 4.4111141837769265
# Stdev: 2.608673487893657
# Min: 0.0
# Max: 9.949580495294754
# Mean: 4.4111141837769265
#
# PAO
# Dim: 30
# Mean: 63.2464447016009
# Stdev: 15.948607265713907
# Min: 38.80335280645636
# Max: 90.54091011974188
# Mean: 63.2464447016009
#
# PAO
# Dim: 50
# Mean: 161.1891531325539
# Stdev: 27.762875371733323
# Min: 116.6224364377693
# Max: 211.11585788396184
# Mean: 161.1891531325539

# %%
for d in [2,5,10,30,50]:
    runs = []
    for _ in range(30):
        runs.append(PSO_h(rastrigin,dim=d,swarm_size=200,max_epoch=500)[1])
    print(f'''PSO-HUGO
Dim: {d}
Mean: {statistics.mean(runs)}
Stdev: {statistics.stdev(runs)}
Min: {min(runs)}
Max: {max(runs)}
Mean: {statistics.mean(runs)}
''')
    data['pso_'][d] = {'dim':d, 'mean':statistics.mean(runs), 'stdev':statistics.stdev(runs),'min':min(runs),'max':max(runs)}
# Out:
# PSO-HUGO
# Dim: 2
# Mean: 2.1863663330160913e-07
# Stdev: 3.010943329732956e-07
# Min: 0.0
# Max: 1.199971709553438e-06
# Mean: 2.1863663330160913e-07
#
# PSO-HUGO
# Dim: 5
# Mean: 1.6147651198919504
# Stdev: 0.9344982162433841
# Min: 6.990025870834415e-05
# Max: 2.9850214584648143
# Mean: 1.6147651198919504
#
# PSO-HUGO
# Dim: 10
# Mean: 8.185293141516837
# Stdev: 3.1964328209543305
# Min: 2.985864000831654
# Max: 15.926046743352998
# Mean: 8.185293141516837
#
# PSO-HUGO
# Dim: 30
# Mean: 26.132005688816843
# Stdev: 5.48523951638471
# Min: 16.472399452438594
# Max: 35.76696601983605
# Mean: 26.132005688816843
#
# PSO-HUGO
# Dim: 50
# Mean: 51.22509608079043
# Stdev: 10.934435476376832
# Min: 31.828623991558914
# Max: 78.51895094616037
# Mean: 51.22509608079043

# %%
for d in [2,5,10,30,50]:
    runs = []
    for _ in range(30):
        runs.append(iwPSO(rastrigin,dim=d,swarm_size=200,max_epoch=500)[1])
    print(f'''iwPSO
Dim: {d}
Mean: {statistics.mean(runs)}
Stdev: {statistics.stdev(runs)}
Min: {min(runs)}
Max: {max(runs)}
Mean: {statistics.mean(runs)}
''')
    data['iwpso'][d] = {'dim':d, 'mean':statistics.mean(runs), 'stdev':statistics.stdev(runs),'min':min(runs),'max':max(runs)}
# Out:
# iwPSO
# Dim: 2
# Mean: 0.0
# Stdev: 0.0
# Min: 0.0
# Max: 0.0
# Mean: 0.0
#
# iwPSO
# Dim: 5
# Mean: 1.1276202647057285
# Stdev: 0.7721669815637233
# Min: 0.0
# Max: 2.9848771712798694
# Mean: 1.1276202647057285
#
# iwPSO
# Dim: 10
# Mean: 7.395859469629326
# Stdev: 2.1496196791710966
# Min: 2.9848771712798907
# Max: 13.929416723667913
# Mean: 7.395859469629326
#
# iwPSO
# Dim: 30
# Mean: 27.402635321567082
# Stdev: 9.726649599757174
# Min: 12.945652863638315
# Max: 48.7624886504278
# Mean: 27.402635321567082
#
# iwPSO
# Dim: 50
# Mean: 49.98610341352776
# Stdev: 14.907331820666085
# Min: 22.257367607449055
# Max: 100.95502901169078
# Mean: 49.98610341352776

# %%
for d in [2,5,10,30,50]:
    runs = []
    for _ in range(30):
        runs.append(DNLPSO_simple(rastrigin,dim=d,swarm_size=200,max_epoch=500)[1])
    print(f'''DNLPSO
Dim: {d}
Mean: {statistics.mean(runs)}
Stdev: {statistics.stdev(runs)}
Min: {min(runs)}
Max: {max(runs)}
Mean: {statistics.mean(runs)}
''')
    data['dnlpso'][d] = {'dim':d, 'mean':statistics.mean(runs), 'stdev':statistics.stdev(runs),'min':min(runs),'max':max(runs)}
# Out:
# DNLPSO
# Dim: 2
# Mean: 0.0
# Stdev: 0.0
# Min: 0.0
# Max: 0.0
# Mean: 0.0
#
# DNLPSO
# Dim: 5
# Mean: 0.9288562635768213
# Stdev: 0.8238142622640496
# Min: 0.0
# Max: 2.9848771712798694
# Mean: 0.9288562635768213
#
# DNLPSO
# Dim: 10
# Mean: 5.638111010231977
# Stdev: 3.084238789933002
# Min: 2.3869617393756926e-08
# Max: 13.929416913594594
# Mean: 5.638111010231977
#
# DNLPSO
# Dim: 30
# Mean: 19.681143826885478
# Stdev: 7.640738005700669
# Min: 11.376013835141237
# Max: 48.36841519636283
# Mean: 19.681143826885478
#
# DNLPSO
# Dim: 50
# Mean: 44.95304394624421
# Stdev: 9.013988950472703
# Min: 27.66159753361393
# Max: 59.63206057088405
# Mean: 44.95304394624421

# %%
import pickle
pickle.dump(data,open('pso200500','wb'))
